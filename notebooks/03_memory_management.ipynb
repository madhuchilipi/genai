# %% [markdown]
# # 03: Memory Management
#
# Add conversation memory to the RAG system.
#
# **Learning Objectives:**
# - Track conversation history
# - Manage context windows
# - Implement summarization

# %%
import sys
sys.path.insert(0, '..')

from src.memory import MemoryManager, ConversationBuffer

print('✓ Imports successful')

# %% [markdown]
# ## Memory Manager
#
# TODO: Implement conversation summarization

# %%
memory = MemoryManager(max_history=10)

# Simulate conversation
memory.add_interaction(
    'What is GDPR?',
    'GDPR is the General Data Protection Regulation...'
)
memory.add_interaction(
    'What are the key principles?',
    'The key principles include lawfulness, fairness...'
)

# Get context
context = memory.get_conversation_context()
print('Conversation context:')
print(context)
