# %% [markdown]
# # 05: Agent RAG
#
# Build autonomous agent with tool use.
#
# **Learning Objectives:**
# - Tool selection
# - Multi-step reasoning
# - LangGraph integration

# %%
import sys
sys.path.insert(0, '..')

from src.agent_rag import AgentRAG

print('✓ Imports successful')

# %% [markdown]
# ## Agent with Tools
#
# TODO: Implement LLM-based tool selection

# %%
agent = AgentRAG()

# Query the agent
response = agent.query('What are GDPR penalties for non-compliance?')
print(f'Response: {response}')

# Get execution trace
trace = agent.get_agent_trace()
print(f'\nTrace: {trace}')
