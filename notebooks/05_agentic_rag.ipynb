# %% [markdown]
# # Milestone 5: Agentic RAG
#
# Multi-agent orchestration with tools:
# 1. Retriever tool
# 2. Citation Checker tool
# 3. Summarizer tool

# %%
import sys
sys.path.insert(0, '..')

from src.rag_baseline import BaselineRAG
from src.agent_rag import AgentRunner, RetrieverTool, CitationCheckerTool
from dotenv import load_dotenv

load_dotenv()
print('✓ Modules imported')

# %% [markdown]
# ## Create Agent with Tools

# %%
rag = BaselineRAG('../faiss_index')
agent = AgentRunner(rag)

result = agent.run('What is Article 17?', check_citations=True)
print(f"Answer: {result['answer'][:150]}...")
print(f"Citation check: {result['citation_check']}")
print(f"Agent workflow: {result['agent_workflow']}")
